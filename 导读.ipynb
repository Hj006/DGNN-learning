# %% [markdown]
# 动态图神经网络（DGNN）相关文献
# “A Comprehensive Survey of Dynamic Graph Neural Networks: Models, Frameworks, Benchmarks, Experiments and Challenges”
# Feng等，2024年（arXiv）：系统梳理了81种DGNN模型、12种框架，提供统一基准实验结果，揭示核心挑战
# journalofbigdata.springeropen.com
# +8
# arxiv.org
# +8
# shuibing9420.github.io
# +8
# 。
#
# “A survey of dynamic graph neural networks”
# Zheng, Yi, Wei，2024年：对主流时序图模型进行分类，讨论预训练与可扩展性等前沿问题
# jmlr.csail.mit.edu
# +4
# arxiv.org
# +4
# dl.acm.org
# +4
# 。
#
# “Foundations and modelling of dynamic networks using Dynamic Graph Neural Networks: A survey”
# Skarding et al.，2020年：建立动态网络统一术语，并综合回顾DGNN研究路线
# sciencedirect.com
# +9
# arxiv.org
# +9
# shuibing9420.github.io
# +9
# 。
#
# “Representation Learning for Dynamic Graphs: A Survey”
# 2020年JMLR论文：从编码器－解码器框架视角系统评述动态图嵌入方法
# jmlr.csail.mit.edu
# 。
#
# ⚙️ ODE 网络（Neural ODE）相关文献
# “Neural Ordinary Differential Equations”
# Chen et al.，2018年：Neural ODE奠基论文，引入连续深度网络与自适应求解器
# aclanthology.org
# +15
# arxiv.org
# +15
# medium.com
# +15
# 。
#
# “On Neural Differential Equations”
# arXiv 2022年博士综述：详细回顾Neural ODE、控制ODE、随机ODE等多种变体
# arxiv.org
# +1
# en.wikipedia.org
# +1
# 。
#
# “HOPE: High-order Graph ODE For Modeling Interacting Dynamics”
# MLR 2023年：将GNN与高阶ODE方法结合，用于不规则时间动态图预测
# activeloop.ai
# +2
# proceedings.mlr.press
# +2
# openreview.net
# +2
# 。
#
# “Physics-informed neural ODE”
# Nature 2023年：结合物理先验，用ODE在潜空间模拟复杂动态
# papers.neurips.cc
# +6
# nature.com
# +6
# reddit.com
# +6
# 。
#
# 🔗 DGNN + ODE 结合方向的文献
# “Graph Neural Ordinary Differential Equations”
# Poli等人，2019年（arXiv）：首次提出GDE框架，将GNN嵌入ODE网络，实现连续深度图表征
# link.springer.com
# +15
# arxiv.org
# +15
# github.com
# +15
# 。
#
# “Signed Graph Neural Ordinary Differential Equation for Modeling ...”
# AAAI论文：进一步将ODE与图神经网络融合，用于符号图建模
# nature.com
# +3
# ojs.aaai.org
# +3
# arxiv.org
# +3
# 。
#
# “Dynamic Graph Neural Ordinary Differential Equation Network for Multi-modal Emotion Recognition in Conversation”
# Shou et al.，2025 COLING：DGODE应用于对话情绪识别，结合动态图结构和ODE演化模型
# arxiv.org
# +1
# aclanthology.org
# +1
# 。
#
# “Integrating GNN and Neural ODEs for Estimating Non-Reciprocal...”
# NeurIPS 2024 Poster：将GNN+ODE用于两体相互作用的动态系统识别
# reddit.com
# +3
# openreview.net
# +3
# medium.com
# +3
# 。
